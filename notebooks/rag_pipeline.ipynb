# %% [markdown]
# ## Import libraries

# %%
import os
import json

from llama_index.core import (
    VectorStoreIndex,
    Settings,
    Document,
    StorageContext,
)
from llama_index.vector_stores.chroma import ChromaVectorStore
from langchain_huggingface import HuggingFaceEmbeddings
from llama_index.embeddings.langchain import LangchainEmbedding
from llama_index.llms.ollama import Ollama

from llama_index.core.chat_engine.types import ChatMode
from llama_index.core.memory import ChatMemoryBuffer
from llama_index.core import ChatPromptTemplate

from prompts import SYSTEM_PROMPT, USER_PROMPT

# %% [markdown]
# ## LLM + Embeddings

# %%
llm = Ollama(
    model='llama_test',
    )

lc_embed_model = HuggingFaceEmbeddings(
    model_name="intfloat/multilingual-e5-small"
)
embed_model = LangchainEmbedding(lc_embed_model)

Settings.llm = llm
Settings.embed_model = embed_model

# %% [markdown]
# ## Vector store

# %%
import chromadb

# create client and a new collection
# chromadb.EphemeralClient saves data in-memory.
chroma_client = chromadb.PersistentClient(path="../chromadb")
chroma_collection = chroma_client.get_collection("rag_database")

vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
index = VectorStoreIndex.from_vector_store(
    vector_store,
    embed_model=embed_model,
)

# %% [markdown]
# # Query Pipeline

# %% [markdown]
# ## Tạo QA Template

# %%
chat_text_qa_msgs = [
    ("system", SYSTEM_PROMPT),
    ("user", USER_PROMPT),
]
text_qa_template = ChatPromptTemplate.from_messages(chat_text_qa_msgs)

# %% [markdown]
# ## Khởi tạo Chat Engine

# %%
memory = ChatMemoryBuffer.from_defaults(token_limit=2048)

chat_engine = index.as_chat_engine(
    similarity_top_k=4,
    response_mode="compact",
    chat_mode=ChatMode.CONTEXT,
    text_qa_template=text_qa_template,
    chat_memory=memory,
)

# %% [markdown]
# ## Hỏi đáp

# %%
# Test the RAG pipeline
def ask_question(question):
    response = chat_engine.chat(question)
    print("Q:", question)
    print("\nA:", response)
    print(f"\nTotal Retrieved Nodes: {len(response.source_nodes)}")
    print("\nRetrieved Nodes:")
    
    for i, node in enumerate(response.source_nodes, 1):
        print(f"\nNode #{i}")
        print(f"Score: {node.score:.4f}")
        print(f"ID: {node.metadata.get('id')}")
        print(f"Unit: {node.metadata.get('unit')}")
        print(f"Section: {node.metadata.get('section')}")
        print(f"Type: {node.metadata.get('type', 'N/A')}")
        print(f"Content Preview: {node.text[:200]}...")
        print("-" * 80)

# %%
# Example questions
questions = [
    "query: Sự khác nhau giữa thì quá khứ đơn và quá khứ tiếp diễn là gì?",
    "query: Cho ví dụ cụ thể về sự khác nhau giữa thì quá khứ đơn và quá khứ tiếp diễn",
    "query: Những lưu ý khi sử dụng thì quá khứ đơn và quá khứ tiếp diễn",
    "query: Công thức tạo câu phủ định trong thì quá khứ đơn",
    "query: Công thức tạo câu phủ định trong thì quá khứ tiếp diễn",
]

for q in questions:
    ask_question(q)
    print("\n" + "-"*80 + "\n")
# Out:
# Q: query: Sự khác nhau giữa thì quá khứ đơn và quá khứ tiếp diễn là gì?
#
# A: Thì quá khứ đơn dùng để diễn tả hành động xảy ra và kết thúc trong một khoảng thời gian xác định, còn thì quá khứ tiếp diễn dùng để diễn tả hành động xảy ra tại một thời điểm xác định trong quá khứ.
#
# Total Retrieved Nodes: 4
#
# Retrieved Nodes:
#
# Node #1
# Score: 0.6760
# ID: page_3_1
# Unit: None
# Section: None
# Type: N/A
# Content Preview: passage:
#
# Type: text
# LỜI NÓI ĐẦU
#
# Tiếng Anh 12 – Global Success – Sách học sinh được Nhà xuất bản Giáo dục Việt Nam
# tổ chức biên soạn theo “Chương trình giáo dục phổ thông: Chương trình môn Tiếng Anh...
# --------------------------------------------------------------------------------
#
# Node #2
# Score: 0.6662
# ID: unit_1_page_14_1
# Unit: Life stories we admire
# Section: SPEAKING
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: SPEAKING
# Type: text
# 2 Work in pairs. A should ask B questions to complete his/her card about Vo Thi Sau. Then B should do the same to complete his/her ca...
# --------------------------------------------------------------------------------
#
# Node #3
# Score: 0.6551
# ID: page_3_1
# Unit: None
# Section: None
# Type: N/A
# Content Preview: Tiếng Anh 12 – Global Success – Sách học sinh coi trọng đặc điểm tâm lí lứa tuổi của
# học sinh và các đặc điểm văn hoá của Việt Nam, của các nước nói tiếng Anh và của các
# nước trên thế giới. Ngoài ra, ...
# --------------------------------------------------------------------------------
#
# Node #4
# Score: 0.6527
# ID: unit_1_page_10_3
# Unit: Life stories we admire
# Section: LANGUAGE
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: LANGUAGE
# Type: list
# 2 Complete the following sentences using the correct forms of the phrases in 1.
# 1. My father _________ in Ha Noi between the age of 1...
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
# Q: query: Cho ví dụ cụ thể về sự khác nhau giữa thì quá khứ đơn và quá khứ tiếp diễn
#
# A: Ví dụ: "You did a great job yesterday." (Bạn à, hôm qua bạn làm rất tốt.) Trong câu này, hành động đã xảy ra và kết thúc vào ngày hôm qua, nên chúng ta dùng thì quá khứ đơn, "did".
#
# Total Retrieved Nodes: 4
#
# Retrieved Nodes:
#
# Node #1
# Score: 0.7190
# ID: unit_1_page_10_3
# Unit: Life stories we admire
# Section: LANGUAGE
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: LANGUAGE
# Type: list
# 2 Complete the following sentences using the correct forms of the phrases in 1.
# 1. My father _________ in Ha Noi between the age of 1...
# --------------------------------------------------------------------------------
#
# Node #2
# Score: 0.7137
# ID: unit_1_page_14_1
# Unit: Life stories we admire
# Section: SPEAKING
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: SPEAKING
# Type: text
# 2 Work in pairs. A should ask B questions to complete his/her card about Vo Thi Sau. Then B should do the same to complete his/her ca...
# --------------------------------------------------------------------------------
#
# Node #3
# Score: 0.7093
# ID: unit_1_page_18_7
# Unit: Life stories we admire
# Section: LOOKING BACK
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: LOOKING BACK
# Type: list
# Vocabulary
#
# Replace each underlined word or phrase with ONE word you have learnt in this unit.
# 1. Uncle Ho **gave** all his love ...
# --------------------------------------------------------------------------------
#
# Node #4
# Score: 0.7089
# ID: unit_1_page_18_9
# Unit: Life stories we admire
# Section: LOOKING BACK
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: LOOKING BACK
# Type: list
# Grammar
#
# Circle the mistake in each sentence. Then correct it.
# 1. When A(I was looking) for some books B(in) the library, I C(was...
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
# Q: query: Những lưu ý khi sử dụng thì quá khứ đơn và quá khứ tiếp diễn
#
# A: Khi sử dụng thì quá khứ đơn, chúng ta cần lưu ý rằng nó dùng để diễn tả hành động xảy ra và kết thúc trong một khoảng thời gian xác định. Trong khi sử dụng thì quá khứ tiếp diễn, chúng ta cần lưu ý rằng nó dùng để diễn tả hành động xảy ra tại một thời điểm xác định trong quá khứ.
#
# Total Retrieved Nodes: 4
#
# Retrieved Nodes:
#
# Node #1
# Score: 0.7254
# ID: page_3_1
# Unit: None
# Section: None
# Type: N/A
# Content Preview: passage:
#
# Type: text
# LỜI NÓI ĐẦU
#
# Tiếng Anh 12 – Global Success – Sách học sinh được Nhà xuất bản Giáo dục Việt Nam
# tổ chức biên soạn theo “Chương trình giáo dục phổ thông: Chương trình môn Tiếng Anh...
# --------------------------------------------------------------------------------
#
# Node #2
# Score: 0.7037
# ID: unit_1_page_14_1
# Unit: Life stories we admire
# Section: SPEAKING
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: SPEAKING
# Type: text
# 2 Work in pairs. A should ask B questions to complete his/her card about Vo Thi Sau. Then B should do the same to complete his/her ca...
# --------------------------------------------------------------------------------
#
# Node #3
# Score: 0.7033
# ID: unit_1_page_13_3
# Unit: Life stories we admire
# Section: GRAMMAR
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: GRAMMAR
# Type: list
# ACTIVITY 1
# Aim: To help Ss recognise the difference between the past simple and the past continuous.
# •	Ask Ss to read the notes in the...
# --------------------------------------------------------------------------------
#
# Node #4
# Score: 0.7027
# ID: unit_1_page_10_7
# Unit: Life stories we admire
# Section: Getting Started
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: Getting Started
# Type: text
# ACTIVITY 4
# Aim: To help Ss identify the past simple and the past continuous.
# •	Tell Ss to read the summary and check understan...
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
# Q: query: Công thức tạo câu phủ định trong thì quá khứ đơn
#
# A: Công thức: "You did not do something yesterday." (Bạn à, hôm qua bạn không làm điều gì đó.) Trong câu này, hành động xảy ra và kết thúc vào ngày hôm qua, nên chúng ta dùng thì quá khứ đơn, "did not".
#
# Total Retrieved Nodes: 4
#
# Retrieved Nodes:
#
# Node #1
# Score: 0.7147
# ID: unit_1_page_10_3
# Unit: Life stories we admire
# Section: LANGUAGE
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: LANGUAGE
# Type: list
# 2 Complete the following sentences using the correct forms of the phrases in 1.
# 1. My father _________ in Ha Noi between the age of 1...
# --------------------------------------------------------------------------------
#
# Node #2
# Score: 0.7029
# ID: unit_1_page_14_1
# Unit: Life stories we admire
# Section: SPEAKING
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: SPEAKING
# Type: text
# 2 Work in pairs. A should ask B questions to complete his/her card about Vo Thi Sau. Then B should do the same to complete his/her ca...
# --------------------------------------------------------------------------------
#
# Node #3
# Score: 0.7027
# ID: unit_1_page_25_3
# Unit: Life stories we admire
# Section: LOOKING BACK
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: LOOKING BACK
# Type: list
# PRONUNCIATION
# Aim: To help Ss review the diphthongs /eɪ/ and /aʊ/.
# •	Ask Ss to read the sentences silently and identify the words...
# --------------------------------------------------------------------------------
#
# Node #4
# Score: 0.6994
# ID: unit_1_page_17_6
# Unit: Life stories we admire
# Section: SPEAKING
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: SPEAKING
# Type: list
# ACTIVITY 3
# Aim: To give Ss an opportunity to present the life stories of two famous heroes.
# •	Put Ss in groups making sure that each ...
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
# Q: query: Công thức tạo câu phủ định trong thì quá khứ tiếp diễn
#
# A: Công thức: "You have not been doing something for the past few days." (Bạn à, trong những ngày qua bạn không làm điều gì đó.) Trong câu này, hành động xảy ra tại một thời điểm xác định trong quá khứ, nên chúng ta dùng thì quá khứ tiếp diễn, "have not been".
#
# Total Retrieved Nodes: 4
#
# Retrieved Nodes:
#
# Node #1
# Score: 0.7028
# ID: unit_1_page_16_3
# Unit: Life stories we admire
# Section: COMMUNICATION AND CULTURE / CLIL
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: COMMUNICATION AND CULTURE / CLIL
# Type: dialogue
# 1 Listen and complete the conversations with the expressions in the box.
# Then practise them in pairs.
# A. ...
# --------------------------------------------------------------------------------
#
# Node #2
# Score: 0.7022
# ID: page_3_1
# Unit: None
# Section: None
# Type: N/A
# Content Preview: passage:
#
# Type: text
# LỜI NÓI ĐẦU
#
# Tiếng Anh 12 – Global Success – Sách học sinh được Nhà xuất bản Giáo dục Việt Nam
# tổ chức biên soạn theo “Chương trình giáo dục phổ thông: Chương trình môn Tiếng Anh...
# --------------------------------------------------------------------------------
#
# Node #3
# Score: 0.7007
# ID: unit_1_page_10_3
# Unit: Life stories we admire
# Section: LANGUAGE
# Type: N/A
# Content Preview: passage: Unit: Life stories we admire
# Section: LANGUAGE
# Type: list
# 2 Complete the following sentences using the correct forms of the phrases in 1.
# 1. My father _________ in Ha Noi between the age of 1...
# --------------------------------------------------------------------------------
#
# Node #4
# Score: 0.7001
# ID: page_1_1
# Unit: None
# Section: None
# Type: N/A
# Content Preview: passage:
#
# Type: text
# HOÀNG VĂN VÂN (Tổng Chủ biên) – VŨ HẢI HÀ (Chủ biên)
# CHU QUANG BÌNH – HOÀNG THỊ HỒNG HẢI
# NGUYỄN THỊ KIM PHƯỢNG
#
# Tiếng Anh
# 12
# SÁCH HỌC SINH
#
# NHÀ XUẤT BẢN GIÁO DỤC VIỆT NAM
# Pearson...
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
